# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as owm

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# import API Key from config file
from api_keys import api_key
# Create settings dictionary with information we're interested in
settings = {"units": "imperial", "appid": api_key}

# Initialize data frame to store data from API calls
WeatherPy_df =pd.DataFrame(columns = ["City","Cloudiness", "Country",
                                    "Date", "Max Temp", "Wind Speed", 
                                    "Lat","Lng", "Humidity"])

# %%
count = 1 # counter to count the number of calls to API
err = 0 # error count to record how many cities the API responds back with no data.
sets = 0 # counter to count the number of call sets
index = 0 # index for the data frame WeatherPy data frame
#Get current time
t0 =time.time()
print(f'Beginning Data Retrieval \n ........................')
for city in cities:
    try:
        city1 = city.replace(" ", "%20") # remove space in city name so the URL retrieved is not broken.
        print(f'Processing Record {count} of Set {sets} | {city}' )
        print(f'{owm.BASE_URL}weather?q={city1}&units=imperial&APPID={api_key}')
        city_stats = owm.get_current(city, **settings)
        WeatherPy_df.set_value(index, "City", city_stats["name"])
        WeatherPy_df.set_value(index, "Cloudiness", city_stats("clouds.all"))
        WeatherPy_df.set_value(index, "Country", city_stats("sys.country"))
        WeatherPy_df.set_value(index, "Date", city_stats("dt"))
        WeatherPy_df.set_value(index, "Max Temp", city_stats("main.temp_max"))
        WeatherPy_df.set_value(index, "Wind Speed", city_stats("wind.speed"))
        WeatherPy_df.set_value(index, "Lat", city_stats("coord.lat"))
        WeatherPy_df.set_value(index, "Lng", city_stats("coord.lon"))
        WeatherPy_df.set_value(index, "Humidity", city_stats("main.humidity"))
        index = index +1 
    except Exception as e:
        print(e)
        err= err+1
    count = count+1
    if count == 51: # loop to limit 50 API calls per minute. The OpenWeatherMap API limit is 60 calls/min
        t1=time.time()
        count = 1 
        sets = sets+1
        time.sleep(60-(t1-t0))
        t0=time.time()

print("end of stats loop")
print(f'Could not get data for {err} cities')
# Out:
# Beginning Data Retrieval
#  ........................
# Processing Record 1 of Set 0 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?q=port%20elizabeth&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# /Users/ImamahYounus/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /Users/ImamahYounus/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# /Users/ImamahYounus/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# /Users/ImamahYounus/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/ImamahYounus/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/ImamahYounus/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/ImamahYounus/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/ImamahYounus/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/ImamahYounus/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing Record 2 of Set 0 | shingu
# http://api.openweathermap.org/data/2.5/weather?q=shingu&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 3 of Set 0 | avarua
# http://api.openweathermap.org/data/2.5/weather?q=avarua&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 4 of Set 0 | hilo
# http://api.openweathermap.org/data/2.5/weather?q=hilo&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 5 of Set 0 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?q=sinnamary&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 6 of Set 0 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 7 of Set 0 | butaritari
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 8 of Set 0 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?q=vestmannaeyjar&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 9 of Set 0 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?q=mount%20gambier&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 10 of Set 0 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 11 of Set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta%20arenas&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 12 of Set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 13 of Set 0 | te anau
# http://api.openweathermap.org/data/2.5/weather?q=te%20anau&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 14 of Set 0 | salalah
# http://api.openweathermap.org/data/2.5/weather?q=salalah&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 15 of Set 0 | qurayyat
# http://api.openweathermap.org/data/2.5/weather?q=qurayyat&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 16 of Set 0 | georgetown
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 17 of Set 0 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?q=cabo%20san%20lucas&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 18 of Set 0 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20ayora&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 19 of Set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 20 of Set 0 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 21 of Set 0 | lagoa
# http://api.openweathermap.org/data/2.5/weather?q=lagoa&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 22 of Set 0 | thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 23 of Set 0 | kapaa
# http://api.openweathermap.org/data/2.5/weather?q=kapaa&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 24 of Set 0 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?q=saint-pierre&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 25 of Set 0 | wanning
# http://api.openweathermap.org/data/2.5/weather?q=wanning&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 26 of Set 0 | bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 27 of Set 0 | chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 28 of Set 0 | san quintin
# http://api.openweathermap.org/data/2.5/weather?q=san%20quintin&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 29 of Set 0 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 30 of Set 0 | furano
# http://api.openweathermap.org/data/2.5/weather?q=furano&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 31 of Set 0 | aklavik
# http://api.openweathermap.org/data/2.5/weather?q=aklavik&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 32 of Set 0 | cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape%20town&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 33 of Set 0 | siyabuswa
# http://api.openweathermap.org/data/2.5/weather?q=siyabuswa&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 34 of Set 0 | wahran
# http://api.openweathermap.org/data/2.5/weather?q=wahran&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 35 of Set 0 | mozarlandia
# http://api.openweathermap.org/data/2.5/weather?q=mozarlandia&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 36 of Set 0 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 37 of Set 0 | baturaja
# http://api.openweathermap.org/data/2.5/weather?q=baturaja&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 38 of Set 0 | slyudyanka
# http://api.openweathermap.org/data/2.5/weather?q=slyudyanka&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 39 of Set 0 | nome
# http://api.openweathermap.org/data/2.5/weather?q=nome&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 40 of Set 0 | port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port%20alfred&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 41 of Set 0 | hasaki
# http://api.openweathermap.org/data/2.5/weather?q=hasaki&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 42 of Set 0 | kodiak
# http://api.openweathermap.org/data/2.5/weather?q=kodiak&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 43 of Set 0 | changli
# http://api.openweathermap.org/data/2.5/weather?q=changli&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 44 of Set 0 | kota kinabalu
# http://api.openweathermap.org/data/2.5/weather?q=kota%20kinabalu&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 45 of Set 0 | erenhot
# http://api.openweathermap.org/data/2.5/weather?q=erenhot&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 46 of Set 0 | saldanha
# http://api.openweathermap.org/data/2.5/weather?q=saldanha&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 47 of Set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 48 of Set 0 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?q=lavrentiya&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 49 of Set 0 | normandin
# http://api.openweathermap.org/data/2.5/weather?q=normandin&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 50 of Set 0 | norman wells
# http://api.openweathermap.org/data/2.5/weather?q=norman%20wells&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 1 of Set 1 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?q=kamenskoye&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 2 of Set 1 | namatanai
# http://api.openweathermap.org/data/2.5/weather?q=namatanai&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 3 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 4 of Set 1 | braslav
# http://api.openweathermap.org/data/2.5/weather?q=braslav&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 5 of Set 1 | muros
# http://api.openweathermap.org/data/2.5/weather?q=muros&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 6 of Set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 7 of Set 1 | guanica
# http://api.openweathermap.org/data/2.5/weather?q=guanica&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 8 of Set 1 | verkh-chebula
# http://api.openweathermap.org/data/2.5/weather?q=verkh-chebula&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 9 of Set 1 | suixi
# http://api.openweathermap.org/data/2.5/weather?q=suixi&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 10 of Set 1 | dibulla
# http://api.openweathermap.org/data/2.5/weather?q=dibulla&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 11 of Set 1 | utiroa
# http://api.openweathermap.org/data/2.5/weather?q=utiroa&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 12 of Set 1 | geraldton
# http://api.openweathermap.org/data/2.5/weather?q=geraldton&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 13 of Set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?q=mar%20del%20plata&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 14 of Set 1 | urumqi
# http://api.openweathermap.org/data/2.5/weather?q=urumqi&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 15 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 16 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?q=mataura&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 17 of Set 1 | husavik
# http://api.openweathermap.org/data/2.5/weather?q=husavik&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 18 of Set 1 | port moresby
# http://api.openweathermap.org/data/2.5/weather?q=port%20moresby&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 19 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?q=barrow&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 20 of Set 1 | malabugas
# http://api.openweathermap.org/data/2.5/weather?q=malabugas&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 21 of Set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q=bambous%20virieux&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 22 of Set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 23 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 24 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 25 of Set 1 | constitucion
# http://api.openweathermap.org/data/2.5/weather?q=constitucion&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 26 of Set 1 | temerloh
# http://api.openweathermap.org/data/2.5/weather?q=temerloh&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 27 of Set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?q=provideniya&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 28 of Set 1 | norfolk
# http://api.openweathermap.org/data/2.5/weather?q=norfolk&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 29 of Set 1 | payo
# http://api.openweathermap.org/data/2.5/weather?q=payo&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 30 of Set 1 | santa catarina de tepehuanes
# http://api.openweathermap.org/data/2.5/weather?q=santa%20catarina%20de%20tepehuanes&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 31 of Set 1 | adrar
# http://api.openweathermap.org/data/2.5/weather?q=adrar&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 32 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial%20do%20cabo&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 33 of Set 1 | ratnapura
# http://api.openweathermap.org/data/2.5/weather?q=ratnapura&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 34 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 35 of Set 1 | beloha
# http://api.openweathermap.org/data/2.5/weather?q=beloha&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 36 of Set 1 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 37 of Set 1 | damaturu
# http://api.openweathermap.org/data/2.5/weather?q=damaturu&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 38 of Set 1 | sibolga
# http://api.openweathermap.org/data/2.5/weather?q=sibolga&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 39 of Set 1 | souillac
# http://api.openweathermap.org/data/2.5/weather?q=souillac&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 40 of Set 1 | bucerias
# http://api.openweathermap.org/data/2.5/weather?q=bucerias&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 41 of Set 1 | riyadh
# http://api.openweathermap.org/data/2.5/weather?q=riyadh&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 42 of Set 1 | laguna
# http://api.openweathermap.org/data/2.5/weather?q=laguna&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 43 of Set 1 | touros
# http://api.openweathermap.org/data/2.5/weather?q=touros&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 44 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 45 of Set 1 | kirensk
# http://api.openweathermap.org/data/2.5/weather?q=kirensk&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 46 of Set 1 | tateyama
# http://api.openweathermap.org/data/2.5/weather?q=tateyama&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 47 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 48 of Set 1 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?q=ixtapa&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 49 of Set 1 | lalomanu
# http://api.openweathermap.org/data/2.5/weather?q=lalomanu&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 50 of Set 1 | soyo
# http://api.openweathermap.org/data/2.5/weather?q=soyo&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 1 of Set 2 | pevek
# http://api.openweathermap.org/data/2.5/weather?q=pevek&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 2 of Set 2 | gamboma
# http://api.openweathermap.org/data/2.5/weather?q=gamboma&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 3 of Set 2 | rio cuarto
# http://api.openweathermap.org/data/2.5/weather?q=rio%20cuarto&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 4 of Set 2 | lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 5 of Set 2 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 6 of Set 2 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 7 of Set 2 | vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 8 of Set 2 | huangchuan
# http://api.openweathermap.org/data/2.5/weather?q=huangchuan&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 9 of Set 2 | cidreira
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 10 of Set 2 | alekseyevsk
# http://api.openweathermap.org/data/2.5/weather?q=alekseyevsk&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 11 of Set 2 | rawson
# http://api.openweathermap.org/data/2.5/weather?q=rawson&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 12 of Set 2 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?q=ostrovnoy&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 13 of Set 2 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?q=belushya%20guba&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 14 of Set 2 | dunedin
# http://api.openweathermap.org/data/2.5/weather?q=dunedin&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 15 of Set 2 | torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 16 of Set 2 | saint george
# http://api.openweathermap.org/data/2.5/weather?q=saint%20george&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 17 of Set 2 | castro
# http://api.openweathermap.org/data/2.5/weather?q=castro&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 18 of Set 2 | olean
# http://api.openweathermap.org/data/2.5/weather?q=olean&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 19 of Set 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 20 of Set 2 | sabang
# http://api.openweathermap.org/data/2.5/weather?q=sabang&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 21 of Set 2 | rock sound
# http://api.openweathermap.org/data/2.5/weather?q=rock%20sound&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 22 of Set 2 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?q=fairbanks&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 23 of Set 2 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 24 of Set 2 | galle
# http://api.openweathermap.org/data/2.5/weather?q=galle&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 25 of Set 2 | macaboboni
# http://api.openweathermap.org/data/2.5/weather?q=macaboboni&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 26 of Set 2 | jilmah
# http://api.openweathermap.org/data/2.5/weather?q=jilmah&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 27 of Set 2 | huancavelica
# http://api.openweathermap.org/data/2.5/weather?q=huancavelica&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 28 of Set 2 | tiksi
# http://api.openweathermap.org/data/2.5/weather?q=tiksi&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 29 of Set 2 | kenai
# http://api.openweathermap.org/data/2.5/weather?q=kenai&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 30 of Set 2 | nerchinskiy zavod
# http://api.openweathermap.org/data/2.5/weather?q=nerchinskiy%20zavod&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 31 of Set 2 | petropavlivka
# http://api.openweathermap.org/data/2.5/weather?q=petropavlivka&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 32 of Set 2 | babanusah
# http://api.openweathermap.org/data/2.5/weather?q=babanusah&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 33 of Set 2 | bassano
# http://api.openweathermap.org/data/2.5/weather?q=bassano&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 34 of Set 2 | katsuura
# http://api.openweathermap.org/data/2.5/weather?q=katsuura&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 35 of Set 2 | sirjan
# http://api.openweathermap.org/data/2.5/weather?q=sirjan&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 36 of Set 2 | emmett
# http://api.openweathermap.org/data/2.5/weather?q=emmett&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 37 of Set 2 | myitkyina
# http://api.openweathermap.org/data/2.5/weather?q=myitkyina&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 38 of Set 2 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?q=kruisfontein&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 39 of Set 2 | cocorit
# http://api.openweathermap.org/data/2.5/weather?q=cocorit&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 40 of Set 2 | cheyenne
# http://api.openweathermap.org/data/2.5/weather?q=cheyenne&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 41 of Set 2 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?q=sao%20filipe&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 42 of Set 2 | batagay
# http://api.openweathermap.org/data/2.5/weather?q=batagay&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 43 of Set 2 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 44 of Set 2 | labuhan
# http://api.openweathermap.org/data/2.5/weather?q=labuhan&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 45 of Set 2 | pandan
# http://api.openweathermap.org/data/2.5/weather?q=pandan&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 46 of Set 2 | traverse city
# http://api.openweathermap.org/data/2.5/weather?q=traverse%20city&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 47 of Set 2 | marau
# http://api.openweathermap.org/data/2.5/weather?q=marau&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 48 of Set 2 | faanui
# http://api.openweathermap.org/data/2.5/weather?q=faanui&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 49 of Set 2 | kholtoson
# http://api.openweathermap.org/data/2.5/weather?q=kholtoson&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 50 of Set 2 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?q=sept-iles&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 1 of Set 3 | codrington
# http://api.openweathermap.org/data/2.5/weather?q=codrington&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 2 of Set 3 | puerto del rosario
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20del%20rosario&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 3 of Set 3 | bahir dar
# http://api.openweathermap.org/data/2.5/weather?q=bahir%20dar&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 4 of Set 3 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?q=udachnyy&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 5 of Set 3 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 6 of Set 3 | moshi
# http://api.openweathermap.org/data/2.5/weather?q=moshi&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 7 of Set 3 | brae
# http://api.openweathermap.org/data/2.5/weather?q=brae&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 8 of Set 3 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 9 of Set 3 | mayari
# http://api.openweathermap.org/data/2.5/weather?q=mayari&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 10 of Set 3 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?q=sioux%20lookout&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 11 of Set 3 | nieuwpoort
# http://api.openweathermap.org/data/2.5/weather?q=nieuwpoort&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 12 of Set 3 | shalinskoye
# http://api.openweathermap.org/data/2.5/weather?q=shalinskoye&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 13 of Set 3 | luau
# http://api.openweathermap.org/data/2.5/weather?q=luau&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 14 of Set 3 | samusu
# http://api.openweathermap.org/data/2.5/weather?q=samusu&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 15 of Set 3 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?q=louisbourg&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 16 of Set 3 | dingle
# http://api.openweathermap.org/data/2.5/weather?q=dingle&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 17 of Set 3 | hohhot
# http://api.openweathermap.org/data/2.5/weather?q=hohhot&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 18 of Set 3 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?q=san%20cristobal&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 19 of Set 3 | bara
# http://api.openweathermap.org/data/2.5/weather?q=bara&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 20 of Set 3 | esperance
# http://api.openweathermap.org/data/2.5/weather?q=esperance&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 21 of Set 3 | port augusta
# http://api.openweathermap.org/data/2.5/weather?q=port%20augusta&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 22 of Set 3 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 23 of Set 3 | ndioum
# http://api.openweathermap.org/data/2.5/weather?q=ndioum&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 24 of Set 3 | tandlianwala
# http://api.openweathermap.org/data/2.5/weather?q=tandlianwala&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 25 of Set 3 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?q=grand%20river%20south%20east&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 26 of Set 3 | east london
# http://api.openweathermap.org/data/2.5/weather?q=east%20london&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 27 of Set 3 | mackay
# http://api.openweathermap.org/data/2.5/weather?q=mackay&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 28 of Set 3 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?q=ambilobe&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 29 of Set 3 | agva
# http://api.openweathermap.org/data/2.5/weather?q=agva&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 30 of Set 3 | changping
# http://api.openweathermap.org/data/2.5/weather?q=changping&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 31 of Set 3 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new%20norfolk&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 32 of Set 3 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 33 of Set 3 | redcliffe
# http://api.openweathermap.org/data/2.5/weather?q=redcliffe&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 34 of Set 3 | lata
# http://api.openweathermap.org/data/2.5/weather?q=lata&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 35 of Set 3 | zagorje ob savi
# http://api.openweathermap.org/data/2.5/weather?q=zagorje%20ob%20savi&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 36 of Set 3 | miri
# http://api.openweathermap.org/data/2.5/weather?q=miri&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 37 of Set 3 | greenville
# http://api.openweathermap.org/data/2.5/weather?q=greenville&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 38 of Set 3 | korla
# http://api.openweathermap.org/data/2.5/weather?q=korla&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 39 of Set 3 | kiyasovo
# http://api.openweathermap.org/data/2.5/weather?q=kiyasovo&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 40 of Set 3 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?q=okhotsk&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 41 of Set 3 | sitka
# http://api.openweathermap.org/data/2.5/weather?q=sitka&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 42 of Set 3 | libertador general san martin
# http://api.openweathermap.org/data/2.5/weather?q=libertador%20general%20san%20martin&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 43 of Set 3 | usogorsk
# http://api.openweathermap.org/data/2.5/weather?q=usogorsk&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 44 of Set 3 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?q=maniitsoq&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 45 of Set 3 | diamantino
# http://api.openweathermap.org/data/2.5/weather?q=diamantino&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 46 of Set 3 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?q=nizhneyansk&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 47 of Set 3 | sao joao do piaui
# http://api.openweathermap.org/data/2.5/weather?q=sao%20joao%20do%20piaui&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 48 of Set 3 | erzin
# http://api.openweathermap.org/data/2.5/weather?q=erzin&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 49 of Set 3 | caravelas
# http://api.openweathermap.org/data/2.5/weather?q=caravelas&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 50 of Set 3 | port hardy
# http://api.openweathermap.org/data/2.5/weather?q=port%20hardy&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 1 of Set 4 | havoysund
# http://api.openweathermap.org/data/2.5/weather?q=havoysund&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 2 of Set 4 | presidente medici
# http://api.openweathermap.org/data/2.5/weather?q=presidente%20medici&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 3 of Set 4 | moss point
# http://api.openweathermap.org/data/2.5/weather?q=moss%20point&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 4 of Set 4 | tucumcari
# http://api.openweathermap.org/data/2.5/weather?q=tucumcari&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 5 of Set 4 | college
# http://api.openweathermap.org/data/2.5/weather?q=college&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 6 of Set 4 | necochea
# http://api.openweathermap.org/data/2.5/weather?q=necochea&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 7 of Set 4 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?q=batemans%20bay&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 8 of Set 4 | dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 9 of Set 4 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?q=srednekolymsk&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 10 of Set 4 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?q=port%20lincoln&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 11 of Set 4 | satitoa
# http://api.openweathermap.org/data/2.5/weather?q=satitoa&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 12 of Set 4 | makat
# http://api.openweathermap.org/data/2.5/weather?q=makat&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 13 of Set 4 | warmbad
# http://api.openweathermap.org/data/2.5/weather?q=warmbad&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 14 of Set 4 | pedro juan caballero
# http://api.openweathermap.org/data/2.5/weather?q=pedro%20juan%20caballero&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 15 of Set 4 | aketi
# http://api.openweathermap.org/data/2.5/weather?q=aketi&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 16 of Set 4 | lexington
# http://api.openweathermap.org/data/2.5/weather?q=lexington&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 17 of Set 4 | la candelaria
# http://api.openweathermap.org/data/2.5/weather?q=la%20candelaria&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 18 of Set 4 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 19 of Set 4 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?q=kloulklubed&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 20 of Set 4 | satkhira
# http://api.openweathermap.org/data/2.5/weather?q=satkhira&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 21 of Set 4 | omboue
# http://api.openweathermap.org/data/2.5/weather?q=omboue&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 22 of Set 4 | gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?q=gornopravdinsk&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 23 of Set 4 | coihaique
# http://api.openweathermap.org/data/2.5/weather?q=coihaique&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 24 of Set 4 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 25 of Set 4 | neuquen
# http://api.openweathermap.org/data/2.5/weather?q=neuquen&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 26 of Set 4 | betioky
# http://api.openweathermap.org/data/2.5/weather?q=betioky&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 27 of Set 4 | ulaanbaatar
# http://api.openweathermap.org/data/2.5/weather?q=ulaanbaatar&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 28 of Set 4 | amderma
# http://api.openweathermap.org/data/2.5/weather?q=amderma&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 29 of Set 4 | rungata
# http://api.openweathermap.org/data/2.5/weather?q=rungata&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 30 of Set 4 | caranavi
# http://api.openweathermap.org/data/2.5/weather?q=caranavi&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 31 of Set 4 | bundaberg
# http://api.openweathermap.org/data/2.5/weather?q=bundaberg&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 32 of Set 4 | narsaq
# http://api.openweathermap.org/data/2.5/weather?q=narsaq&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 33 of Set 4 | ocos
# http://api.openweathermap.org/data/2.5/weather?q=ocos&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 34 of Set 4 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?q=mys%20shmidta&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# HTTP Error 404: Not Found
# Processing Record 35 of Set 4 | huarmey
# http://api.openweathermap.org/data/2.5/weather?q=huarmey&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 36 of Set 4 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?q=tuatapere&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 37 of Set 4 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?q=cap%20malheureux&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 38 of Set 4 | verkhnyaya inta
# http://api.openweathermap.org/data/2.5/weather?q=verkhnyaya%20inta&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 39 of Set 4 | sangar
# http://api.openweathermap.org/data/2.5/weather?q=sangar&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 40 of Set 4 | kropotkin
# http://api.openweathermap.org/data/2.5/weather?q=kropotkin&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 41 of Set 4 | heihe
# http://api.openweathermap.org/data/2.5/weather?q=heihe&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 42 of Set 4 | freetown
# http://api.openweathermap.org/data/2.5/weather?q=freetown&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 43 of Set 4 | baykit
# http://api.openweathermap.org/data/2.5/weather?q=baykit&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 44 of Set 4 | vanavara
# http://api.openweathermap.org/data/2.5/weather?q=vanavara&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 45 of Set 4 | kununurra
# http://api.openweathermap.org/data/2.5/weather?q=kununurra&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 46 of Set 4 | sechura
# http://api.openweathermap.org/data/2.5/weather?q=sechura&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 47 of Set 4 | karaidel
# http://api.openweathermap.org/data/2.5/weather?q=karaidel&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 48 of Set 4 | upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 49 of Set 4 | weligama
# http://api.openweathermap.org/data/2.5/weather?q=weligama&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316
# Processing Record 50 of Set 4 | xiamen
# http://api.openweathermap.org/data/2.5/weather?q=xiamen&units=imperial&APPID=6fa14c4b9ab01f264498309d9894a316

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Display the count of cities with weather data
WeatherPy_df.count()

# %%
# save to csv file
WeatherPy_df.output_data_file("Cities.csv", encoding='utf-8', index=False)

# Display the city weather data frame
WeatherPy_df.head(10)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(10,8))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Max Temp"], color='r', alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temperature ({datetime.now().date()})')
plt.savefig("LatVsTemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,6))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Humidity"], color='blue', alpha=0.5)
plt.ylim(10,120)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity ({datetime.now().date()})')
plt.savefig("LatVsHumidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(8,6))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Cloudiness"], color='green', alpha=0.5)

plt.ylim(-20,(WeatherPy_df["Cloudiness"].max()+10))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness ({datetime.now().date()})')
plt.savefig("LatVsCloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(8,6))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Wind Speed"], color='orange', alpha=0.5)

plt.ylim((WeatherPy_df["Wind Speed"].min()-5),(WeatherPy_df["Wind Speed"].max()+5))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed ({datetime.now().date()})')
plt.savefig("LatVsWind.png")
plt.show()
